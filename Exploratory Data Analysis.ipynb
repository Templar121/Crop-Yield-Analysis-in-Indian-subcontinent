# %% [markdown]
# # Importing Necessary Libraries

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# # Reading the dataset

# %%
df = pd.read_csv("crop_yield.csv")

# %%
df.head()
# Out:
#            Crop  Crop_Year       Season  State     Area  Production  \
# 0      Arecanut       1997  Whole Year   Assam  73814.0       56708
# 1     Arhar/Tur       1997  Kharif       Assam   6637.0        4685
# 2   Castor seed       1997  Kharif       Assam    796.0          22
# 3      Coconut        1997  Whole Year   Assam  19656.0   126905000
# 4  Cotton(lint)       1997  Kharif       Assam   1739.0         794
#
#    Annual_Rainfall  Fertilizer  Pesticide        Yield
# 0           2051.4  7024878.38   22882.34     0.796087
# 1           2051.4   631643.29    2057.47     0.710435
# 2           2051.4    75755.32     246.76     0.238333
# 3           2051.4  1870661.52    6093.36  5238.051739
# 4           2051.4   165500.63     539.09     0.420909

# %%
df.shape
# Out:
# (19689, 10)

# %%
df.columns
# Out:
# Index(['Crop', 'Crop_Year', 'Season', 'State', 'Area', 'Production',
#        'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  object
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  object
#  3   State            19689 non-null  object
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int64(2), object(3)
# memory usage: 1.5+ MB

# %%
df.isnull().sum()
# Out:
# Crop               0
# Crop_Year          0
# Season             0
# State              0
# Area               0
# Production         0
# Annual_Rainfall    0
# Fertilizer         0
# Pesticide          0
# Yield              0
# dtype: int64

# %%
df['Crop'].value_counts()
# Out:
# Crop
# Rice                     1197
# Maize                     975
# Moong(Green Gram)         740
# Urad                      733
# Groundnut                 725
# Sesamum                   685
# Potato                    628
# Sugarcane                 605
# Wheat                     545
# Rapeseed &Mustard         528
# Bajra                     524
# Jowar                     513
# Arhar/Tur                 508
# Ragi                      498
# Gram                      490
# Small millets             485
# Cotton(lint)              476
# Onion                     454
# Sunflower                 441
# Dry chillies              419
# Other Kharif pulses       382
# Horse-gram                371
# Peas & beans (Pulses)     369
# Tobacco                   364
# Other  Rabi pulses        355
# Soyabean                  349
# Turmeric                  337
# Masoor                    324
# Ginger                    323
# Linseed                   308
# Castor seed               300
# ...

# %%
df['Crop_Year'].value_counts()
# Out:
# Crop_Year
# 2019    1079
# 2017    1070
# 2018    1063
# 2016    1036
# 2015     998
# 2013     976
# 2014     965
# 2011     907
# 2012     894
# 2009     865
# 2010     859
# 2008     847
# 2007     828
# 2006     823
# 2002     815
# 2005     811
# 2003     801
# 2004     787
# 2000     772
# 2001     750
# 1999     650
# 1998     646
# 1997     410
# 2020      37
# Name: count, dtype: int64

# %%
df['Season'].value_counts()
# Out:
# Season
# Kharif         8232
# Rabi           5742
# Whole Year     3717
# Summer         1195
# Autumn          414
# Winter          389
# Name: count, dtype: int64

# %%
df['State'].value_counts()
# Out:
# State
# Karnataka            1432
# Andhra Pradesh       1266
# West Bengal          1094
# Chhattisgarh          915
# Bihar                 896
# Madhya Pradesh        845
# Uttar Pradesh         825
# Tamil Nadu            822
# Gujarat               817
# Maharashtra           770
# Uttarakhand           764
# Odisha                760
# Assam                 731
# Nagaland              689
# Puducherry            670
# Meghalaya             649
# Haryana               631
# Jammu and Kashmir     631
# Himachal Pradesh      616
# Kerala                534
# Manipur               444
# Tripura               441
# Mizoram               416
# Telangana             397
# Punjab                397
# Arunachal Pradesh     292
# Jharkhand             270
# Goa                   246
# Sikkim                226
# Delhi                 203
# Name: count, dtype: int64

# %%
df.columns
# Out:
# Index(['Crop', 'Crop_Year', 'Season', 'State', 'Area', 'Production',
#        'Annual_Rainfall', 'Fertilizer', 'Pesticide', 'Yield'],
#       dtype='object')

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Crop'], y = df['Yield'], data = df, hue = df['State'])
plt.xticks(rotation=45)
plt.show()

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Crop_Year'], y = df['Yield'], data = df, hue = df['State'])
# Out:
# <Axes: xlabel='Crop_Year', ylabel='Yield'>

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Season'], y = df['Yield'], data = df, hue = df['State'])
# Out:
# <Axes: xlabel='Season', ylabel='Yield'>

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Area'], y = df['Yield'], data = df, hue = df['State'])
# Out:
# <Axes: xlabel='Area', ylabel='Yield'>

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Production'], y = df['Yield'], data = df, hue = df['State'])
# Out:
# <Axes: xlabel='Production', ylabel='Yield'>

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Annual_Rainfall'], y = df['Yield'], data = df, hue = df['State'])
# Out:
# <Axes: xlabel='Annual_Rainfall', ylabel='Yield'>

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Fertilizer'], y = df['Yield'], data = df, hue = df['State'])
# Out:
# <Axes: xlabel='Fertilizer', ylabel='Yield'>

# %%
plt.figure(figsize = (20, 12))
sns.scatterplot(x = df['Pesticide'], y = df['Yield'], data = df, hue = df['State'])
# Out:
# <Axes: xlabel='Pesticide', ylabel='Yield'>

# %%
plt.figure(figsize = (20, 8))
sns.countplot(x = df['Crop_Year'], data = df)
# Out:
# <Axes: xlabel='Crop_Year', ylabel='count'>

# %%
plt.figure(figsize = (20, 8))
sns.countplot(x = df['Season'], data = df)
# Out:
# <Axes: xlabel='Season', ylabel='count'>

# %% [markdown]
# # Encoding Categorical values to Numerical Values using Label encoders

# %%
from sklearn.preprocessing import LabelEncoder, StandardScaler

# %%
label_encoder = LabelEncoder()
df['Crop'] = label_encoder.fit_transform(df['Crop'])
df['Season'] = label_encoder.fit_transform(df['Season'])
df['State'] = label_encoder.fit_transform(df['State'])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 19689 entries, 0 to 19688
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Crop             19689 non-null  int32
#  1   Crop_Year        19689 non-null  int64
#  2   Season           19689 non-null  int32
#  3   State            19689 non-null  int32
#  4   Area             19689 non-null  float64
#  5   Production       19689 non-null  int64
#  6   Annual_Rainfall  19689 non-null  float64
#  7   Fertilizer       19689 non-null  float64
#  8   Pesticide        19689 non-null  float64
#  9   Yield            19689 non-null  float64
# dtypes: float64(5), int32(3), int64(2)
# memory usage: 1.3 MB

# %%
df.head()
# Out:
#    Crop  Crop_Year  Season  State     Area  Production  Annual_Rainfall  \
# 0     0       1997       4      2  73814.0       56708           2051.4
# 1     1       1997       1      2   6637.0        4685           2051.4
# 2     8       1997       1      2    796.0          22           2051.4
# 3     9       1997       4      2  19656.0   126905000           2051.4
# 4    11       1997       1      2   1739.0         794           2051.4
#
#    Fertilizer  Pesticide        Yield
# 0  7024878.38   22882.34     0.796087
# 1   631643.29    2057.47     0.710435
# 2    75755.32     246.76     0.238333
# 3  1870661.52    6093.36  5238.051739
# 4   165500.63     539.09     0.420909

# %% [markdown]
# # Plotting the Distribution of the various Features

# %%
sns.distplot(x = df['Crop'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df['Crop_Year'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df['Season'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df['State'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df['Production'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df['Annual_Rainfall'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df['Fertilizer'])
# Out:
# <Axes: ylabel='Density'>

# %%
sns.distplot(x = df['Pesticide'])
# Out:
# <Axes: ylabel='Density'>
